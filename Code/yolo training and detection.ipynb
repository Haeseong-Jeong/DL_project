# %% [markdown]
# [참고]
#
# https://velog.io/@ajs3801/Yolo-PyTorch-custom-dataset-%ED%95%99%EC%8A%B5%EC%8B%9C%ED%82%A4%EA%B8%B0-3

# %% [markdown]
# ## darknet git clone

# %%
# !git clone https://github.com/pjreddie/darknet.git
# Out:
# Cloning into 'darknet'...

# %% [markdown]
# ## path in darnket folder

# %%
cd darknet
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: 'darknet'
# D:\YOLO_V5\darknet

# %% [markdown]
# ## check the path

# %%
import os
print(os.getcwd())
# Out:
# D:\YOLO_V5\darknet

# %%
# !dir
# Out:
#  D 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 901C-098F
#
#  D:\YOLO_V5\darknet 디렉터리
#
# 2023-10-17  오후 07:02    <DIR>          .
# 2023-10-17  오후 07:02    <DIR>          ..
# 2023-10-17  오후 07:02               227 .gitignore
# 2023-10-17  오후 07:02    <DIR>          cfg
# 2023-10-17  오후 07:02    <DIR>          data
# 2023-10-17  오후 07:02    <DIR>          examples
# 2023-10-17  오후 07:02    <DIR>          include
# 2023-10-17  오후 07:02               527 LICENSE
# 2023-10-17  오후 07:02               487 LICENSE.fuck
# 2023-10-17  오후 07:02             6,743 LICENSE.gen
# 2023-10-17  오후 07:02            35,815 LICENSE.gpl
# 2023-10-17  오후 07:02               368 LICENSE.meta
# 2023-10-17  오후 07:02             1,093 LICENSE.mit
# 2023-10-17  오후 07:02               474 LICENSE.v1
# 2023-10-17  오후 07:02             3,145 Makefile
# 2023-10-17  오후 07:02    <DIR>          python
# 2023-10-17  오후 07:02             5,196 README.md
# 2023-10-17  오후 07:02    <DIR>          scripts
# 2023-10-17  오후 07:02    <DIR>          src
#               10개 파일              54,075 바이트
#                9개 디렉터리  877,989,593,088 바이트 남음

# %% [markdown]
# ## Makefile modify

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Make makefile

# %%
cmd -> 경로변경 -> make

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
